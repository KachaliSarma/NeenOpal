# %%
pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import opendatasets as od
import pandas as pd
import numpy as np
import os

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c4484a8-5e72-4178-ba42-a80f619e9dc6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c4484a8-5e72-4178-ba42-a80f619e9dc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1=pd.read_excel('/content/Records Matching Task.xlsx',sheet_name="data1")

# %%
df2=pd.read_excel('/content/Records Matching Task.xlsx',sheet_name="data2")

# %%
df1.head()
# Out:
#          Order ID       Product ID  Qty
# 0  CA-2014-100006  TEC-PH-10002075  3.0
# 1  CA-2014-100090  FUR-TA-10003715  3.0
# 2  CA-2014-100090  OFF-BI-10001597  6.0
# 3  CA-2014-100293  OFF-PA-10000176  6.0
# 4  CA-2014-100328  OFF-BI-10000343  1.0

# %%
df1.isnull().sum() #no of null values
# Out:
# Order ID      0
# Product ID    0
# Qty           0
# dtype: int64

# %%
df2.head()
# Out:
#          Order ID       Product ID  Qty
# 0  CA-2014-100090  FUR-TA-10003715  3.0
# 1  CA-2014-100090  OFF-BI-10001597  6.0
# 2  CA-2014-100293  OFF-PA-10000176  6.0
# 3  CA-2014-100328  OFF-BI-10000343  1.0
# 4  CA-2014-100363  OFF-FA-10000611  2.0

# %%
df2.isnull().sum() #no of null values
# Out:
# Order ID      0
# Product ID    0
# Qty           0
# dtype: int64

# %% [markdown]
# ## Creating Primary Key

# %%
df1["Record1"] = df1["Order ID"]+df1["Product ID"] #for data 1
df2["Record2"] = df2["Order ID"]+df2["Product ID"] #for data 2

# %%
df1.head()
# Out:
#          Order ID       Product ID  Qty                        Record1
# 0  CA-2014-100006  TEC-PH-10002075  3.0  CA-2014-100006TEC-PH-10002075
# 1  CA-2014-100090  FUR-TA-10003715  3.0  CA-2014-100090FUR-TA-10003715
# 2  CA-2014-100090  OFF-BI-10001597  6.0  CA-2014-100090OFF-BI-10001597
# 3  CA-2014-100293  OFF-PA-10000176  6.0  CA-2014-100293OFF-PA-10000176
# 4  CA-2014-100328  OFF-BI-10000343  1.0  CA-2014-100328OFF-BI-10000343

# %%
df2.head()
# Out:
#          Order ID       Product ID  Qty                        Record2
# 0  CA-2014-100090  FUR-TA-10003715  3.0  CA-2014-100090FUR-TA-10003715
# 1  CA-2014-100090  OFF-BI-10001597  6.0  CA-2014-100090OFF-BI-10001597
# 2  CA-2014-100293  OFF-PA-10000176  6.0  CA-2014-100293OFF-PA-10000176
# 3  CA-2014-100328  OFF-BI-10000343  1.0  CA-2014-100328OFF-BI-10000343
# 4  CA-2014-100363  OFF-FA-10000611  2.0  CA-2014-100363OFF-FA-10000611

# %%
## Now we will merge data 1 and data 2 

total_df = df1.merge(df2, how='outer', left_on=['Record1'], right_on=['Record2'])
total_df
# Out:
#           Order ID_x     Product ID_x  Qty_x                        Record1  \
# 0     CA-2014-100006  TEC-PH-10002075    3.0  CA-2014-100006TEC-PH-10002075
# 1     CA-2014-100090  FUR-TA-10003715    3.0  CA-2014-100090FUR-TA-10003715
# 2     CA-2014-100090  OFF-BI-10001597    6.0  CA-2014-100090OFF-BI-10001597
# 3     CA-2014-100293  OFF-PA-10000176    6.0  CA-2014-100293OFF-PA-10000176
# 4     CA-2014-100328  OFF-BI-10000343    1.0  CA-2014-100328OFF-BI-10000343
# ...              ...              ...    ...                            ...
# 9981             NaN              NaN    NaN                            NaN
# 9982             NaN              NaN    NaN                            NaN
# 9983             NaN              NaN    NaN                            NaN
# 9984             NaN              NaN    NaN                            NaN
# 9985             NaN              NaN    NaN                            NaN
#
# ...

# %%
total_df.isnull().sum()
# Out:
# Order ID_x      508
# Product ID_x    508
# Qty_x           508
# Record1         508
# Order ID_y      507
# Product ID_y    507
# Qty_y           507
# Record2         507
# dtype: int64

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### How to identify the Records (Order ID + Product ID combination) present in data1 but missing in data2 (Specify the number of records missing in your answer)

# %%
# we collect columns where record 2 is null
# and save it in different dataframe
task1 = total_df[total_df['Record2'].isnull()]
task1
# Out:
#           Order ID_x     Product ID_x  Qty_x                        Record1  \
# 0     CA-2014-100006  TEC-PH-10002075    3.0  CA-2014-100006TEC-PH-10002075
# 10    CA-2014-100678  OFF-EN-10000056    3.0  CA-2014-100678OFF-EN-10000056
# 19    CA-2014-100895  OFF-AR-10004511    2.0  CA-2014-100895OFF-AR-10004511
# 35    CA-2014-101560  OFF-BI-10000309    3.0  CA-2014-101560OFF-BI-10000309
# 61    CA-2014-102673  OFF-LA-10001771   12.0  CA-2014-102673OFF-LA-10001771
# ...              ...              ...    ...                            ...
# 9390  US-2017-160836  OFF-AP-10001626    2.0  US-2017-160836OFF-AP-10001626
# 9403  US-2017-162558  FUR-FU-10002364    2.0  US-2017-162558FUR-FU-10002364
# 9420  US-2017-163657  OFF-BI-10000138    5.0  US-2017-163657OFF-BI-10000138
# 9427  US-2017-164056  FUR-TA-10001307    5.0  US-2017-164056FUR-TA-10001307
# 9435  US-2017-165456  FUR-CH-10003981    6.0  US-2017-165456FUR-CH-10003981
#
#      Order ID_y Product ID_y  Qty_y Record2
# ...

# %%
task1.shape
# Out:
# (507, 8)

# %% [markdown]
# ## 507

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### How to identify the Records (Order ID + Product ID combination) missing in data1 but present in data2 (Specify the number of records missing in your answer)

# %%
# we collect columns where record 1 is null
# and save it in different dataframe
task2 = total_df[total_df['Record1'].isna()]
task2
# Out:
#      Order ID_x Product ID_x  Qty_x Record1      Order ID_y     Product ID_y  \
# 9478        NaN          NaN    NaN     NaN  CA-2014-100706  TEC-AC-10001314
# 9479        NaN          NaN    NaN     NaN  CA-2014-100762  OFF-PA-10001815
# 9480        NaN          NaN    NaN     NaN  CA-2014-101427  OFF-AR-10002257
# 9481        NaN          NaN    NaN     NaN  CA-2014-102652  FUR-FU-10001918
# 9482        NaN          NaN    NaN     NaN  CA-2014-102869  OFF-PA-10000788
# ...         ...          ...    ...     ...             ...              ...
# 9981        NaN          NaN    NaN     NaN  US-2017-165344  OFF-BI-10003196
# 9982        NaN          NaN    NaN     NaN  US-2017-165358  TEC-CO-10001943
# 9983        NaN          NaN    NaN     NaN  US-2017-167920  OFF-AP-10000159
# 9984        NaN          NaN    NaN     NaN  US-2017-169502  OFF-AP-10001947
# 9985        NaN          NaN    NaN     NaN  US-2017-169551  FUR-BO-10001519
#
#       Qty_y                        Record2
# ...

# %%
task2.shape
# Out:
# (508, 8)

# %% [markdown]
# ## 508

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Find the Sum of the total Qty of Records missing in data1 but present in data2

# %%
task2['Qty_y'].sum()
# Out:
# 1956.0

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Find the total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2

# %%
total_df.shape[0]
# Out:
# 9986
